# %%
# %load_ext rpy2.ipython

# %%
# %%R
# spec <- read.delim('chroma/data/SEDs/snflux_1a.dat', sep='', head=F)
# print(head(spec))
# Out:
#    V1   V2           V3
# 1 -20 1000 1.300029e-38
# 2 -20 1010 1.300029e-38
# 3 -20 1020 1.300029e-38
# 4 -20 1030 1.300029e-38
# 5 -20 1040 1.300029e-38
# 6 -20 1050 1.300029e-38

# %%
# %R which(spec$V2==max(spec$V2))
# Out:
# array([  2401,   4802,   7203,   9604,  12005,  14406,  16807,  19208,
#         21609,  24010,  26411,  28812,  31213,  33614,  36015,  38416,
#         40817,  43218,  45619,  48020,  50421,  52822,  55223,  57624,
#         60025,  62426,  64827,  67228,  69629,  72030,  74431,  76832,
#         79233,  81634,  84035,  86436,  88837,  91238,  93639,  96040,
#         98441, 100842, 103243, 105644, 108045, 110446, 112847, 115248,
#        117649, 120050, 122451, 124852, 127253, 129654, 132055, 134456,
#        136857, 139258, 141659, 144060, 146461, 148862, 151263, 153664,
#        156065, 158466, 160867, 163268, 165669, 168070, 170471, 172872,
#        175273, 177674, 180075, 182476, 184877, 187278, 189679, 192080,
#        194481, 196882, 199283, 201684, 204085, 206486, 208887, 211288,
#        213689, 216090, 218491, 220892, 223293, 225694, 228095, 230496,
#        232897, 235298, 237699, 240100, 242501, 244902, 247303, 249704,
#        252105, 254506], dtype=int32)

# %%
# %R plot(spec$V2[252105+1:254506], spec$V3[252105+1:254506], typ='l')
